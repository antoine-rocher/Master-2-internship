# %%
# %pylab inline

# %%
smu=loadtxt('../CLPT_GSRSD-master/data/xi_s.txt_2d').T

rpar=linspace(0,15,50)
rp=linspace(0,40,64)
xis = smu[2]
xis.shape = (50,64)

#cmap = plt.get_cmap("gist_heat_r")
#bounds = np.logspace(-2, 1.5, 20, base=10)
#norm = BoundaryNorm(boundaries=bounds, ncolors=256)

plt.contour(rp, rpar, xis, levels=[0.04,0.08, 0.2, 0.4, 0.8], alpha=0.8, colors='k',norm=norm)

# %%
s,mu,xis = loadtxt("../CLPT_GSRSD-master/data/xi_s.txt_2d", unpack=True)

rper = mu*s
spar = sqrt(s*s-rper*rper)
result= zeros((len(s),3))
for i in range(len(s)):
    result[i,0] = rper[i]
    result[i,1] = spar[i]
    result[i,2] = xis[i]

result.sort(key=x[2])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-62-b2a27dc0b00b> in <module>
#       9     result[i,2] = xis[i]
#      10
# ---> 11 result.sort(key=x[2])
#
# TypeError: 'key' is an invalid keyword argument for sort()

# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from matplotlib.colors import *
import scipy.ndimage as ndimage
nb=1291
x=np.linspace(0,100,nb)

fig = plt.figure(1,figsize=(17,18))
#plt.xlabel("$r_p$  [$h^{-1}$ Mpc]", fontsize=20)
#plt.ylabel("$\pi$  [$h^{-1}$ Mpc]", fontsize=20)

# ----- bin 1

data = np.loadtxt('code_GSRSD/hearin/Xi_s_CLPT_hearin.dat').T
arr = data[2]
arr.shape = (nb,nb)
#arr = arr.transpose()
data1 = np.loadtxt('code_GSRSD/hearin/Xi_s_Pk_hearin.dat').T
arr1 = data1[2]
arr1.shape = (nb,nb)
#arr = arr.transpose()
plt.axis([0,70,0,40])
#plt.set_aspect('equal', adjustable='box')
plt.axes().set_aspect('equal', adjustable='box')

cmap = plt.get_cmap("gist_heat_r")
bounds = np.logspace(-2, 1.5, 20, base=10)
norm = BoundaryNorm(boundaries=bounds, ncolors=256)


'''
plt.pcolormesh(x,x,arr, alpha=1, cmap=cmap, norm=norm)
plt.pcolormesh(-x,x,arr, alpha=1, cmap=cmap, norm=norm)
plt.pcolormesh(x,-x,arr, alpha=1, cmap=cmap, norm=norm)
plt.pcolormesh(-x,-x,arr, alpha=1, cmap=cmap, norm=norm)

'''
#cb1 = plt.contourf(x, x,   arr, levels=[0.01,0.1, 0.25, 0.5, 1, 10,50], alpha=0.8, cmap=cmap, norm=norm)
#plt.contourf(-x, x,  arr, levels=[0.01,0.1, 0.25, 0.5, 1, 10,50], alpha=0.8, cmap=cmap, norm=norm)
#plt.contourf(x, -x,  arr, levels=[0.01,0.1, 0.25, 0.5, 1, 10,50], alpha=0.8, cmap=cmap, norm=norm)
#plt.contourf(-x, -x, arr, levels=[0.01,0.1, 0.25, 0.5, 1, 10,50], alpha=0.8, cmap=cmap, norm=norm)

plt.contour(x, x,   arr, levels=[0.01,0.04,0.1, 0.2, 0.4, 0.8], alpha=0.8, colors='k',norm=norm,label='CLPT')
#plt.contour(-x, x,  arr, levels=[0.01,0.04,0.1, 0.2, 0.4, 0.8], alpha=0.8, colors='k',norm=norm)
#plt.contour(x, -x,  arr, levels=[0.01,0.04,0.1, 0.2, 0.4, 0.8], alpha=0.8, colors='k',norm=norm)
#plt.contour(-x, -x, arr, levels=[0.01,0.04,0.1, 0.2, 0.4, 0.8], alpha=0.8, colors='k',norm=norm)

plt.contour(x, x,   arr1, levels=[0.01,0.04,0.1, 0.2, 0.4, 0.8], alpha=0.8, colors='k',norm=norm, linestyles='dashed', label='GS')
#plt.contour(-x, x,  arr1, levels=[0.01,0.04,0.1, 0.2, 0.4, 0.8], alpha=0.8, colors='k',norm=norm, linestyles='dashed')
#plt.contour(x, -x,  arr1, levels=[0.01,0.04,0.1, 0.2, 0.4, 0.8], alpha=0.8, colors='k',norm=norm, linestyles='dashed')
#plt.contour(-x, -x, arr1, levels=[0.01,0.04,0.1, 0.2, 0.4, 0.8], alpha=0.8, colors='k',norm=norm,linestyles='dashed')
legend()
plt.savefig('code_GSRSD/RSD_comp_GS_CLTP.png', bbox_inches='tight')
plt.show()
# Out:
# /home/arocher/.local/lib/python3.7/site-packages/matplotlib/figure.py:98: MatplotlibDeprecationWarning:
# Adding an axes using the same arguments as a previous axes currently reuses the earlier instance.  In a future version, a new instance will always be created and returned.  Meanwhile, this warning can be suppressed, and the future behavior ensured, by passing a unique label to each axes instance.
#   "Adding an axes using the same arguments as a previous axes "
# /home/arocher/.local/lib/python3.7/site-packages/matplotlib/contour.py:1000: UserWarning: The following kwargs were not used by contour: 'label'
#   s)
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-31aa9ec06e63> in <module>
#      51 #plt.contour(x, -x,  arr1, levels=[0.01,0.04,0.1, 0.2, 0.4, 0.8], alpha=0.8, colors='k',norm=norm, linestyles='dashed')
# ...

# %%
len(arr)
# Out:
# 50

# %%
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from matplotlib.colors import *
import scipy.ndimage as ndimage
nb=1291
x=np.linspace(0,100,nb)
fig = plt.figure(1,figsize=(17,18))
#plt.xlabel("$r_p$  [$h^{-1}$ Mpc]", fontsize=20)
#plt.ylabel("$\pi$  [$h^{-1}$ Mpc]", fontsize=20)

# ----- bin 1

data = np.loadtxt('code_GSRSD/hearin/Xi_s_CLPT_hearin.dat').T
arr = data[2]
arr.shape = (nb,nb)
#arr = arr.transpose()

plt.axis([-50,50,-20,20])
#plt.set_aspect('equal', adjustable='box')
plt.axes().set_aspect('equal', adjustable='box')

cmap = plt.get_cmap("gist_heat_r")
bounds = np.logspace(-2, 1.5, 20, base=10)
norm = BoundaryNorm(boundaries=bounds, ncolors=256)

plt.pcolormesh(x,x,arr, alpha=1, cmap=cmap, norm=norm)
plt.pcolormesh(-x,x,arr, alpha=1, cmap=cmap, norm=norm)
plt.pcolormesh(x,-x,arr, alpha=1, cmap=cmap, norm=norm)
plt.pcolormesh(-x,-x,arr, alpha=1, cmap=cmap, norm=norm)

'''
cb1 = plt.contourf(x, x,   arr, levels=[0.01,0.1, 0.25, 0.5, 1, 10,50], alpha=0.8, cmap=cmap, norm=norm)
plt.contourf(-x, x,  arr, levels=[0.01,0.1, 0.25, 0.5, 1, 10,50], alpha=0.8, cmap=cmap, norm=norm)
plt.contourf(x, -x,  arr, levels=[0.01,0.1, 0.25, 0.5, 1, 10,50], alpha=0.8, cmap=cmap, norm=norm)
plt.contourf(-x, -x, arr, levels=[0.01,0.1, 0.25, 0.5, 1, 10,50], alpha=0.8, cmap=cmap, norm=norm)

plt.contour(x, x,   arr, levels=[0.01,0.1, 0.25, 0.5, 1, 10,50], alpha=0.8, colors='k',norm=norm)
plt.contour(-x, x,  arr, levels=[0.01,0.1, 0.25, 0.5, 1, 10,50], alpha=0.8, colors='k',norm=norm)
plt.contour(x, -x,  arr, levels=[0.01,0.1, 0.25, 0.5, 1, 10,50], alpha=0.8, colors='k',norm=norm)
plt.contour(-x, -x, arr, levels=[0.01,0.1, 0.25, 0.5, 1, 10,50], alpha=0.8, colors='k',norm=norm)
'''

#plt.savefig('RDS_GS_b_1.png', bbox_inches='tight')
plt.show()

# %%
x,y,z = np.loadtxt("../CLPT_GSRSD-master/data_simu/xi_s.txt_2d", unpack=True)
plt.contour(x.reshape(80,40), y.reshape(80,40), z.reshape(80,40))

# %%
import scipy
from scipy import interpolate
xi = np.linspace(0, 80, 100)
yi = np.linspace(0, 80, 100)
zi = scipy.interpolate.griddata(x, y, z, (xi, yi),method='cubic2D')
plt.contour(xi, yi, zi)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-148-caae02bd8fbc> in <module>
#       3 xi = np.linspace(0, 80, 100)
#       4 yi = np.linspace(0, 80, 100)
# ----> 5 zi = scipy.interpolate.griddata(x, y, z, (xi, yi),method='cubic2D')
#       6 plt.contour(xi, yi, zi)
#
# TypeError: griddata() got multiple values for argument 'method'

# %%
X, Y = np.meshgrid(x, y)
Z = f(X,Y)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-125-00faad4241e5> in <module>
#       1 X, Y = np.meshgrid(x, y)
# ----> 2 Z = f(X,Y)
#
# <ipython-input-111-14c97b18bd49> in f(x, y)
#       2     z= array([])
#       3     for i in range (len(data)):
# ----> 4         if  data[i,0] == y[i]:
#       5             if data[i,1] == y[i]:
#       6                 z = append(z,data[i,2])
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()

# %%
arr1 = np.zeros(64*64)
for i in range (len(z)):
    arr1[i]+=z[i]
arr1.shape = (64,64)
x=np.linspace(0,100,64)
plt.contourf(x, -x, arr1, colors='black')

# %%
def f(x, y):
    return np.sin(x) ** 10 + np.cos(10 + y * x) * np.cos(x)



x = np.linspace(0, 5, 50)
y = np.linspace(0, 5, 40)

X, Y = np.meshgrid(x, y)
Z = f(X, Y)

plt.contour(X, Y, Z, colors='black')

# %%
# Out:
# array([[-0.83907153, -0.83470697, -0.8216586 , ...,  0.8956708 ,
#          0.68617261,  0.41940746],
#        [-0.83907153, -0.8275558 , -0.80744041, ...,  0.93467448,
#          0.77467433,  0.55894214],
#        [-0.83907153, -0.820263  , -0.79266951, ...,  0.98503397,
#          0.88847607,  0.73757604],
#        ...,
#        [-0.83907153, -0.48696962, -0.02692065, ...,  0.98525345,
#          0.79584263,  0.46799565],
#        [-0.83907153, -0.47558005, -0.00130271, ...,  0.93488414,
#          0.6993547 ,  0.37933079],
#        [-0.83907153, -0.46410908,  0.02431613, ...,  0.89579384,
#          0.65690314,  0.40107702]])
